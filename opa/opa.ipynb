# %%
import requests
from pprint import pprint
import json

# https://www.openpolicyagent.org/docs/latest/rest-api/
URL_PREFIX = 'http://localhost:8181'

headers = {
    'content-type': 'application/json'
}

def _dump(r):
    print(f'\nResponse:\n{r.status_code}')
    try:
        pprint(r.json())
    except:
        print(r.text)

# %% [markdown]
# # Policy
#
# The Policy API exposes CRUD endpoints for managing policy modules. Policy modules can be added, removed, and modified at any time.

# %% [markdown]
# ## List Policies

# %%
url = URL_PREFIX + '/v1/policies'
print(url)
params = {}
r = requests.get(url=url, headers=headers, params=params)
_dump(r)
# Out:
# http://localhost:8181/v1/policies
#
# Response:
# 200
# {'result': [{'ast': {'comments': [{'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 5},
#                                    'Text': 'IHVubGVzcyBvdGhlcndpc2UgZGVmaW5lZCwgYWxsb3cgaXMgZmFsc2U='},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 7},
#                                    'Text': 'IGFsbG93IGlzIHRydWUgaWYuLi4='},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 8},
#                                    'Text': 'IHRoZXJlIGFyZSB6ZXJvIHZpb2xhdGlvbnMu'},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 11},
#                                    'Text': 'IGEgc2VydmVyIGlzIGluIHRoZSB2aW9sYXRpb24gc2V0IGlmLi4u'},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 13},
#                                    'Text': 'IGl0IGV4aXN0cyBpbiB0aGUgJ3B1YmxpY19zZXJ2ZXInIHNldCBhbmQuLi4='},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 14},
#                                    'Text': 'IGl0IGNvbnRhaW5zIHRoZSBpbnNlY3VyZSAiaHR0cCIgcHJvdG9jb2wu'},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 17},
#                                    'Text': 'IGEgc2VydmVyIGlzIGluIHRoZSB2aW9sYXRpb24gc2V0IGlmLi4u'},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 18},
#                                    'Text': 'IGl0IGV4aXN0cyBpbiB0aGUgaW5wdXQuc2VydmVycyBjb2xsZWN0aW9uIGFuZC4uLg=='},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 19},
#                                    'Text': 'IGl0IGNvbnRhaW5zIHRoZSAidGVsbmV0IiBwcm90b2NvbC4='},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 22},
#                                    'Text': 'IGEgc2VydmVyIGV4aXN0cyBpbiB0aGUgcHVibGljX3NlcnZlciBzZXQgaWYuLi4='},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 24},
#                                    'Text': 'IGl0IGV4aXN0cyBpbiB0aGUgaW5wdXQuc2VydmVycyBjb2xsZWN0aW9uIGFuZC4uLg=='},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 25},
#                                    'Text': 'IGl0IHJlZmVyZW5jZXMgYSBwb3J0IGluIHRoZSBpbnB1dC5wb3J0cyBjb2xsZWN0aW9uIGFuZC4uLg=='},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 26},
#                                    'Text': 'IHRoZSBwb3J0IHJlZmVyZW5jZXMgYSBuZXR3b3JrIGluIHRoZSBpbnB1dC5uZXR3b3JrcyBjb2xsZWN0aW9uIGFuZC4uLg=='},
#                                   {'Location': {'col': 53,
#                                                 'file': '/opa-examples/example.rego',
#                                                 'row': 27},
#                                    'Text': 'IHRoZSBuZXR3b3JrIGlzIHB1YmxpYy4='}],
#                      'package': {'path': [{'type': 'var', 'value': 'data'},
#                                           {'type': 'string',
#                                            'value': 'example'}]},
#                      'rules': [{'body': [{'index': 0,
#                                           'terms': {'type': 'boolean',
#                                                     'value': True}}],
#                                 'default': True,
#                                 'head': {'assign': True,
#                                          'name': 'allow',
#                                          'ref': [{'type': 'var',
#                                                   'value': 'allow'}],
#                                          'value': {'type': 'boolean',
#                                                    'value': False}}},
#                                {'body': [{'generated': True,
#                                           'index': 0,
#                                           'terms': [{'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'eq'}]},
#                                                     {'type': 'var',
#                                                      'value': '__local8__'},
#                                                     {'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'data'},
#                                                                {'type': 'string',
#                                                                 'value': 'example'},
#                                                                {'type': 'string',
#                                                                 'value': 'violation'}]}]},
#                                          {'generated': True,
#                                           'index': 1,
#                                           'terms': [{'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'count'}]},
#                                                     {'type': 'var',
#                                                      'value': '__local8__'},
#                                                     {'type': 'var',
#                                                      'value': '__local5__'}]},
#                                          {'index': 2,
#                                           'terms': [{'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'eq'}]},
#                                                     {'type': 'var',
#                                                      'value': '__local5__'},
#                                                     {'type': 'number',
#                                                      'value': 0}]}],
#                                 'head': {'name': 'allow',
#                                          'ref': [{'type': 'var',
#                                                   'value': 'allow'}],
#                                          'value': {'type': 'boolean',
#                                                    'value': True}}},
#                                {'body': [{'index': 0,
#                                           'terms': {'type': 'ref',
#                                                     'value': [{'type': 'var',
#                                                                'value': 'data'},
#                                                               {'type': 'string',
#                                                                'value': 'example'},
#                                                               {'type': 'string',
#                                                                'value': 'public_server'},
#                                                               {'type': 'var',
#                                                                'value': '__local0__'}]}},
#                                          {'index': 1,
#                                           'terms': [{'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'eq'}]},
#                                                     {'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': '__local0__'},
#                                                                {'type': 'string',
#                                                                 'value': 'protocols'},
#                                                                {'type': 'var',
#                                                                 'value': '$0'}]},
#                                                     {'type': 'string',
#                                                      'value': 'http'}]},
#                                          {'generated': True,
#                                           'index': 2,
#                                           'terms': [{'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'eq'}]},
#                                                     {'type': 'var',
#                                                      'value': '__local6__'},
#                                                     {'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': '__local0__'},
#                                                                {'type': 'string',
#                                                                 'value': 'id'}]}]}],
#                                 'head': {'key': {'type': 'var',
#                                                  'value': '__local6__'},
#                                          'name': 'violation',
#                                          'ref': [{'type': 'var',
#                                                   'value': 'violation'}]}},
#                                {'body': [{'index': 0,
#                                           'terms': [{'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'eq'}]},
#                                                     {'type': 'var',
#                                                      'value': '__local1__'},
#                                                     {'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'input'},
#                                                                {'type': 'string',
#                                                                 'value': 'servers'},
#                                                                {'type': 'var',
#                                                                 'value': '$1'}]}]},
#                                          {'index': 1,
#                                           'terms': [{'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'eq'}]},
#                                                     {'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': '__local1__'},
#                                                                {'type': 'string',
#                                                                 'value': 'protocols'},
#                                                                {'type': 'var',
#                                                                 'value': '$2'}]},
#                                                     {'type': 'string',
#                                                      'value': 'telnet'}]},
#                                          {'generated': True,
#                                           'index': 2,
#                                           'terms': [{'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'eq'}]},
#                                                     {'type': 'var',
#                                                      'value': '__local7__'},
#                                                     {'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': '__local1__'},
#                                                                {'type': 'string',
#                                                                 'value': 'id'}]}]}],
#                                 'head': {'key': {'type': 'var',
#                                                  'value': '__local7__'},
#                                          'name': 'violation',
#                                          'ref': [{'type': 'var',
#                                                   'value': 'violation'}]}},
#                                {'body': [{'index': 0,
#                                           'terms': [{'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'eq'}]},
#                                                     {'type': 'var',
#                                                      'value': '__local4__'},
#                                                     {'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'input'},
#                                                                {'type': 'string',
#                                                                 'value': 'servers'},
#                                                                {'type': 'var',
#                                                                 'value': '$3'}]}]},
#                                          {'index': 1,
#                                           'terms': [{'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'eq'}]},
#                                                     {'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': '__local4__'},
#                                                                {'type': 'string',
#                                                                 'value': 'ports'},
#                                                                {'type': 'var',
#                                                                 'value': '$4'}]},
#                                                     {'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'input'},
#                                                                {'type': 'string',
#                                                                 'value': 'ports'},
#                                                                {'type': 'var',
#                                                                 'value': '__local2__'},
#                                                                {'type': 'string',
#                                                                 'value': 'id'}]}]},
#                                          {'index': 2,
#                                           'terms': [{'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'eq'}]},
#                                                     {'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'input'},
#                                                                {'type': 'string',
#                                                                 'value': 'ports'},
#                                                                {'type': 'var',
#                                                                 'value': '__local2__'},
#                                                                {'type': 'string',
#                                                                 'value': 'network'}]},
#                                                     {'type': 'ref',
#                                                      'value': [{'type': 'var',
#                                                                 'value': 'input'},
#                                                                {'type': 'string',
#                                                                 'value': 'networks'},
#                                                                {'type': 'var',
#                                                                 'value': '__local3__'},
#                                                                {'type': 'string',
#                                                                 'value': 'id'}]}]},
#                                          {'index': 3,
#                                           'terms': {'type': 'ref',
#                                                     'value': [{'type': 'var',
#                                                                'value': 'input'},
#                                                               {'type': 'string',
#                                                                'value': 'networks'},
#                                                               {'type': 'var',
#                                                                'value': '__local3__'},
#                                                               {'type': 'string',
#                                                                'value': 'public'}]}}],
#                                 'head': {'key': {'type': 'var',
#                                                  'value': '__local4__'},
#                                          'name': 'public_server',
#                                          'ref': [{'type': 'var',
#                                                   'value': 'public_server'}]}}]},
#              'id': 'opa-examples/example.rego',
#              'raw': 'package example\r\n'
#                     '\r\n'
#                     'import rego.v1\r\n'
#                     '\r\n'
#                     'default allow := false                              # '
#                     'unless otherwise defined, allow is false\r\n'
#                     '\r\n'
#                     'allow if {                                          # '
#                     'allow is true if...\r\n'
#                     '    count(violation) == 0                           # '
#                     'there are zero violations.\r\n'
#                     '}\r\n'
#                     '\r\n'
#                     'violation contains server.id if {                   # a '
#                     'server is in the violation set if...\r\n'
#                     '    some server\r\n'
#                     '    public_server[server]                           # it '
#                     "exists in the 'public_server' set and...\r\n"
#                     '    server.protocols[_] == "http"                   # it '
#                     'contains the insecure "http" protocol.\r\n'
#                     '}\r\n'
#                     '\r\n'
#                     'violation contains server.id if {                   # a '
#                     'server is in the violation set if...\r\n'
#                     '    server := input.servers[_]                      # it '
#                     'exists in the input.servers collection and...\r\n'
#                     '    server.protocols[_] == "telnet"                 # it '
#                     'contains the "telnet" protocol.\r\n'
#                     '}\r\n'
#                     '\r\n'
#                     'public_server contains server if {                  # a '
#                     'server exists in the public_server set if...\r\n'
#                     '    some i, j\r\n'
#                     '    server := input.servers[_]                      # it '
#                     'exists in the input.servers collection and...\r\n'
#                     '    server.ports[_] == input.ports[i].id            # it '
#                     'references a port in the input.ports collection and...\r\n'
#                     '    input.ports[i].network == input.networks[j].id  # the '
#                     'port references a network in the input.networks '
#                     'collection and...\r\n'
#                     '    input.networks[j].public                        # the '
#                     'network is public.\r\n'
#                     '}'}]}

# %% [markdown]
# ## Get a Policy

# %%
policy_id = 'example1'
url = URL_PREFIX + f'/v1/policies/{policy_id}'
print(url)
params = {}
r = requests.get(url=url, headers=headers, params=params)
_dump(r)
# Out:
# http://localhost:8181/v1/policies/example1
#
# Response:
# 200
# {'result': {'ast': {'package': {'path': [{'type': 'var', 'value': 'data'},
#                                          {'type': 'string',
#                                           'value': 'system'}]},
#                     'rules': [{'body': [{'generated': True,
#                                          'index': 0,
#                                          'terms': [{'type': 'ref',
#                                                     'value': [{'type': 'var',
#                                                                'value': 'eq'}]},
#                                                    {'type': 'var',
#                                                     'value': '__local10__'},
#                                                    {'type': 'ref',
#                                                     'value': [{'type': 'var',
#                                                                'value': 'input'},
#                                                               {'type': 'string',
#                                                                'value': 'user'}]}]},
#                                         {'generated': True,
#                                          'index': 1,
#                                          'terms': [{'type': 'ref',
#                                                     'value': [{'type': 'var',
#                                                                'value': 'sprintf'}]},
#                                                    {'type': 'string',
#                                                     'value': 'hello, %v'},
#                                                    {'type': 'array',
#                                                     'value': [{'type': 'var',
#                                                                'value': '__local10__'}]},
#                                                    {'type': 'var',
#                                                     'value': '__local6__'}]},
#                                         {'index': 2,
#                                          'terms': [{'type': 'ref',
#                                                     'value': [{'type': 'var',
#                                                                'value': 'eq'}]},
#                                                    {'type': 'var',
#                                                     'value': '__local0__'},
#                                                    {'type': 'var',
#                                                     'value': '__local6__'}]}],
#                                'head': {'assign': True,
#                                         'name': 'main',
#                                         'ref': [{'type': 'var',
#                                                  'value': 'main'}],
#                                         'value': {'type': 'var',
#                                                   'value': '__local0__'}}}]},
#             'id': 'example1',
#             'raw': 'package system\n'
#                    '\n'
#                    'import rego.v1\n'
#                    '\n'
#                    'main := msg if {\n'
#                    '\tmsg := sprintf("hello, %v", [input.user])\n'
#                    '}'}}

# %% [markdown]
# ## Create/Update a Policy

# %%
headers['content-type'] = 'text/plain'

policy_id = 'example1'
url = URL_PREFIX + f'/v1/policies/{policy_id}'
params = {}
data = """package system

import rego.v1

main := msg if {
	msg := sprintf("hello, %v", [input.user])
}"""
r = requests.put(url=url, headers=headers, params=params, data=data)
_dump(r)
headers['content-type'] = 'application/json'
# Out:
# Response:
# 200
# {}

# %% [markdown]
# ## Delete a Policy

# %%
policy_id = 'example1'
url = URL_PREFIX + f'/v1/policies/{policy_id}'
params = {}
r = requests.delete(url=url, headers=headers, params=params, data=data)
_dump(r)
# Out:
# 200
# {}

# %% [markdown]
# # Data
#
# The Data API exposes endpoints for reading and writing documents in OPA.

# %% [markdown]
# ## Create/Overwrite a Document

# %%
input_json = {
    "servers": [
        {"id": "app", "protocols": ["https", "ssh"], "ports": ["p1", "p2", "p3"]},
        {"id": "db", "protocols": ["mysql"], "ports": ["p3"]},
        {"id": "cache", "protocols": ["memcache"], "ports": ["p3"]},
        {"id": "ci", "protocols": ["http"], "ports": ["p1", "p2"]},
        {"id": "busybox", "protocols": ["telnet"], "ports": ["p1"]}
    ],
    "networks": [
        {"id": "net1", "public": False},
        {"id": "net2", "public": False},
        {"id": "net3", "public": True},
        {"id": "net4", "public": True}
    ],
    "ports": [
        {"id": "p1", "network": "net1"},
        {"id": "p2", "network": "net3"},
        {"id": "p3", "network": "net2"}
    ]
}

# %%
data_path = '/examples/input1.json'

# %%
url = URL_PREFIX + f'/v1/data{data_path}'
print(url)
params = {}
data = input_json
print(f'Request:\nurl={url}\nheaders={headers}\nparms={params}\ndata={data}')

r = requests.put(url=url, headers=headers, params=params, data=json.dumps(data))
_dump(r)
# Out:
# http://localhost:8181/v1/data/examples/input1.json
# Request:
# url=http://localhost:8181/v1/data/examples/input1.json
# headers={'content-type': 'application/json'}
# parms={}
# data={'servers': [{'id': 'app', 'protocols': ['https', 'ssh'], 'ports': ['p1', 'p2', 'p3']}, {'id': 'db', 'protocols': ['mysql'], 'ports': ['p3']}, {'id': 'cache', 'protocols': ['memcache'], 'ports': ['p3']}, {'id': 'ci', 'protocols': ['http'], 'ports': ['p1', 'p2']}, {'id': 'busybox', 'protocols': ['telnet'], 'ports': ['p1']}], 'networks': [{'id': 'net1', 'public': False}, {'id': 'net2', 'public': False}, {'id': 'net3', 'public': True}, {'id': 'net4', 'public': True}], 'ports': [{'id': 'p1', 'network': 'net1'}, {'id': 'p2', 'network': 'net3'}, {'id': 'p3', 'network': 'net2'}]}
#
# Response:
# 204

# %% [markdown]
# ## Get a Document

# %%
url = URL_PREFIX + '/v1/data' + data_path
print(url)
params = {}
r = requests.get(url=url, headers=headers, params=params)
_dump(r)
# Out:
# http://localhost:8181/v1/data/examples/input1.json
#
# Response:
# 200
# {'decision_id': 'bdfdbacb-ce31-4ea9-8d46-6e8cef24b03d',
#  'result': {'networks': [{'id': 'net1', 'public': False},
#                          {'id': 'net2', 'public': False},
#                          {'id': 'net3', 'public': True},
#                          {'id': 'net4', 'public': True}],
#             'ports': [{'id': 'p1', 'network': 'net1'},
#                       {'id': 'p2', 'network': 'net3'},
#                       {'id': 'p3', 'network': 'net2'}],
#             'servers': [{'id': 'app',
#                          'ports': ['p1', 'p2', 'p3'],
#                          'protocols': ['https', 'ssh']},
#                         {'id': 'db', 'ports': ['p3'], 'protocols': ['mysql']},
#                         {'id': 'cache',
#                          'ports': ['p3'],
#                          'protocols': ['memcache']},
#                         {'id': 'ci',
#                          'ports': ['p1', 'p2'],
#                          'protocols': ['http']},
#                         {'id': 'busybox',
#                          'ports': ['p1'],
#                          'protocols': ['telnet']}]}}

# %% [markdown]
# ## Delete a Document

# %%
url = URL_PREFIX + '/v1/data' + data_path
print(url)
params = {}
r = requests.delete(url=url, headers=headers, params=params)
_dump(r)
# Out:
# http://localhost:8181/v1/data/examples/input1.json
# 204

# %% [markdown]
# # Query

# %% [markdown]
# ## Simple Query
#
# If the default decision (defaulting to `/system/main`) is undefined, the server returns 404.

# %%
# with policy 'example1' created
url = URL_PREFIX
print(url)
params = {}
data = {
  "user": ["alice"]
}
r = requests.post(url=url, headers=headers, params=params, data=json.dumps(data))
_dump(r)
# Out:
# http://localhost:8181
#
# Response:
# 200
# 'hello, ["alice"]'

# %% [markdown]
# ## Ad-hoc Query

# %%
# with policy 'example1' created
url = URL_PREFIX + '/v1/query'
params = {
    'pretty': True,
    'explain': 'debug', # notes, fails, full, debug
}
query = '''input.servers[i].ports[_] = "p2"; input.servers[i].id = id'''
data = {
    "query": query,
    "input": input_json
}
print(f'Request:\nurl={url}\nheaders={headers}\nparms={params}\ndata={data}')

r = requests.post(url=url, headers=headers, params=params, data=json.dumps(data))
_dump(r)
# Out:
# Request:
# url=http://localhost:8181/v1/query
# headers={'content-type': 'application/json'}
# parms={'pretty': True, 'explain': 'debug'}
# data={'query': 'input.servers[i].ports[_] = "p2"; input.servers[i].id = id', 'input': {'servers': [{'id': 'app', 'protocols': ['https', 'ssh'], 'ports': ['p1', 'p2', 'p3']}, {'id': 'db', 'protocols': ['mysql'], 'ports': ['p3']}, {'id': 'cache', 'protocols': ['memcache'], 'ports': ['p3']}, {'id': 'ci', 'protocols': ['http'], 'ports': ['p1', 'p2']}, {'id': 'busybox', 'protocols': ['telnet'], 'ports': ['p1']}], 'networks': [{'id': 'net1', 'public': False}, {'id': 'net2', 'public': False}, {'id': 'net3', 'public': True}, {'id': 'net4', 'public': True}], 'ports': [{'id': 'p1', 'network': 'net1'}, {'id': 'p2', 'network': 'net3'}, {'id': 'p3', 'network': 'net2'}]}}
#
# Response:
# 200
# {'explanation': ['query:1     Enter input.servers[i].ports[_] = "p2"; '
#                  'input.servers[i].id = id',
#                  'query:1     | Eval input.servers[i].ports[_] = "p2"',
#                  'query:1     | Unify input.servers[i].ports[_] = "p2"',
#                  'query:1     | Unify 0 = i',
#                  'query:1     | Unify 0 = _',
#                  'query:1     | Unify "p1" = "p2"',
#                  'query:1     | Unify 1 = _',
#                  'query:1     | Unify "p2" = "p2"',
#                  'query:1     | Eval input.servers[i].id = id',
#                  'query:1     | Unify input.servers[i].id = id',
#                  'query:1     | Unify "app" = id',
#                  'query:1     | Exit input.servers[i].ports[_] = "p2"; '
#                  'input.servers[i].id = id',
#                  'query:1     Redo input.servers[i].ports[_] = "p2"; '
#                  'input.servers[i].id = id',
#                  'query:1     | Redo input.servers[i].id = id',
#                  'query:1     | Redo input.servers[i].ports[_] = "p2"',
#                  'query:1     | Unify 2 = _',
#                  'query:1     | Unify "p3" = "p2"',
#                  'query:1     | Unify 1 = i',
#                  'query:1     | Unify 0 = _',
#                  'query:1     | Unify "p3" = "p2"',
#                  'query:1     | Unify 2 = i',
#                  'query:1     | Unify 0 = _',
#                  'query:1     | Unify "p3" = "p2"',
#                  'query:1     | Unify 3 = i',
#                  'query:1     | Unify 0 = _',
#                  'query:1     | Unify "p1" = "p2"',
#                  'query:1     | Unify 1 = _',
#                  'query:1     | Unify "p2" = "p2"',
#                  'query:1     | Eval input.servers[i].id = id',
#                  'query:1     | Unify input.servers[i].id = id',
#                  'query:1     | Unify "ci" = id',
#                  'query:1     | Exit input.servers[i].ports[_] = "p2"; '
#                  'input.servers[i].id = id',
#                  'query:1     Redo input.servers[i].ports[_] = "p2"; '
#                  'input.servers[i].id = id',
#                  'query:1     | Redo input.servers[i].id = id',
#                  'query:1     | Redo input.servers[i].ports[_] = "p2"',
#                  'query:1     | Unify 4 = i',
#                  'query:1     | Unify 0 = _',
#                  'query:1     | Unify "p1" = "p2"'],
#  'result': [{'i': 0, 'id': 'app'}, {'i': 3, 'id': 'ci'}]}

# %% [markdown]
# # Compile

# %% [markdown]
# # Health

# %%
url = URL_PREFIX + '/health'
params = {}
print(f'Request:\nurl={url}\nheaders={headers}\nparms={params}')

r = requests.get(url=url, headers=headers, params=params)
_dump(r)
# Out:
# Request:
# url=http://localhost:8181/health
# headers={'content-type': 'application/json'}
# parms={}
#
# Response:
# 200
# {}

# %%
url = URL_PREFIX + '/health?bundles'
params = {}
print(f'Request:\nurl={url}\nheaders={headers}\nparms={params}')

r = requests.get(url=url, headers=headers, params=params)
_dump(r)
# Out:
# Request:
# url=http://localhost:8181/health?bundles
# headers={'content-type': 'application/json'}
# parms={}
#
# Response:
# 200
# {}

# %%
url = URL_PREFIX + '/health?plugins'
params = {}
print(f'Request:\nurl={url}\nheaders={headers}\nparms={params}')

r = requests.get(url=url, headers=headers, params=params)
_dump(r)
# Out:
# Request:
# url=http://localhost:8181/health?plugins
# headers={'content-type': 'application/json'}
# parms={}
#
# Response:
# 200
# {}

# %% [markdown]
# # Config

# %%
url = URL_PREFIX + '/v1/config'
params = {}
print(f'Request:\nurl={url}\nheaders={headers}\nparms={params}')

r = requests.get(url=url, headers=headers, params=params)
_dump(r)
# Out:
# Request:
# url=http://localhost:8181/v1/config
# headers={'content-type': 'application/json'}
# parms={}
#
# Response:
# 200
# {'result': {'decision_logs': {'console': True,
#                               'reporting': {'max_delay_seconds': 600,
#                                             'min_delay_seconds': 300},
#                               'service': 'example'},
#             'default_authorization_decision': '/system/authz/allow',
#             'default_decision': '/system/main',
#             'labels': {'id': 'b256d0c3-9ec4-4530-b3dc-ebd69c69edeb',
#                        'version': '0.60.0'},
#             'lables': {'environment': 'dev',
#                        'region': 'dev',
#                        'service': 'example'},
#             'persistence_directory': '/var/opa',
#             'services': {'example': {'response_header_timeout_seconds': 5,
#                                      'url': 'http://localhost:8181/policy/v1'}},
#             'status': {'service': 'example'}}}

# %% [markdown]
# # Status

# %%
url = URL_PREFIX + '/v1/status'
params = {}
print(f'Request:\nurl={url}\nheaders={headers}\nparms={params}')

r = requests.get(url=url, headers=headers, params=params)
_dump(r)
# Out:
# Request:
# url=http://localhost:8181/v1/status
# headers={'content-type': 'application/json'}
# parms={}
#
# Response:
# 200
# {'result': {'decision_logs': {'code': 'decision_log_error',
#                               'http_code': 404,
#                               'message': 'log upload failed, server replied '
#                                          'with HTTP 404 Not Found'},
#             'labels': {'id': 'b256d0c3-9ec4-4530-b3dc-ebd69c69edeb',
#                        'version': '0.60.0'},
#             'metrics': {'prometheus': {'counter_enc_soft_limit_scale_up': 1,
#                                        'go_cgo_go_to_c_calls_calls_total': {'help': 'Count '
#                                                                                     'of '
#                                                                                     'calls '
#                                                                                     'made '
#                                                                                     'from '
#                                                                                     'Go '
#                                                                                     'to '
#                                                                                     'C '
#                                                                                     'by '
#                                                                                     'the '
#                                                                                     'current '
#                                                                                     'process.',
#                                                                             'metric': [{'counter': {'value': 2}}],
#                                                                             'name': 'go_cgo_go_to_c_calls_calls_total',
#                                                                             'type': 'COUNTER'},
#                                        'go_cpu_classes_gc_mark_assist_cpu_seconds_total': {'help': 'Estimated '
#                                                                                                    'total '
#                                                                                                    'CPU '
#                                                                                                    'time '
#                                                                                                    'goroutines '
#                                                                                                    'spent '
#                                                                                                    'performing '
#                                                                                                    'GC '
#                                                                                                    'tasks '
#                                                                                                    'to '
#                                                                                                    'assist '
#                                                                                                    'the '
#                                                                                                    'GC '
#                                                                                                    'and '
#                                                                                                    'prevent '
#                                                                                                    'it '
#                                                                                                    'from '
#                                                                                                    'falling '
#                                                                                                    'behind '
#                                                                                                    'the '
#                                                                                                    'application. '
#                                                                                                    'This '
#                                                                                                    'metric '
#                                                                                                    'is '
#                                                                                                    'an '
#                                                                                                    'overestimate, '
#                                                                                                    'and '
#                                                                                                    'not '
#                                                                                                    'directly '
#                                                                                                    'comparable '
#                                                                                                    'to '
#                                                                                                    'system '
#                                                                                                    'CPU '
#                                                                                                    'time '
#                                                                                                    'measurements. '
#                                                                                                    'Compare '
#                                                                                                    'only '
#                                                                                                    'with '
#                                                                                                    'other '
#                                                                                                    '/cpu/classes '
#                                                                                                    'metrics.',
#                                                                                            'metric': [{'counter': {'value': 0.003449426}}],
#                                                                                            'name': 'go_cpu_classes_gc_mark_assist_cpu_seconds_total',
#                                                                                            'type': 'COUNTER'},
#                                        'go_cpu_classes_gc_mark_dedicated_cpu_seconds_total': {'help': 'Estimated '
#                                                                                                       'total '
#                                                                                                       'CPU '
#                                                                                                       'time '
#                                                                                                       'spent '
#                                                                                                       'performing '
#                                                                                                       'GC '
#                                                                                                       'tasks '
#                                                                                                       'on '
#                                                                                                       'processors '
#                                                                                                       '(as '
#                                                                                                       'defined '
#                                                                                                       'by '
#                                                                                                       'GOMAXPROCS) '
#                                                                                                       'dedicated '
#                                                                                                       'to '
#                                                                                                       'those '
#                                                                                                       'tasks. '
#                                                                                                       'This '
#                                                                                                       'metric '
#                                                                                                       'is '
#                                                                                                       'an '
#                                                                                                       'overestimate, '
#                                                                                                       'and '
#                                                                                                       'not '
#                                                                                                       'directly '
#                                                                                                       'comparable '
#                                                                                                       'to '
#                                                                                                       'system '
#                                                                                                       'CPU '
#                                                                                                       'time '
#                                                                                                       'measurements. '
#                                                                                                       'Compare '
#                                                                                                       'only '
#                                                                                                       'with '
#                                                                                                       'other '
#                                                                                                       '/cpu/classes '
#                                                                                                       'metrics.',
#                                                                                               'metric': [{'counter': {'value': 0.03347201}}],
#                                                                                               'name': 'go_cpu_classes_gc_mark_dedicated_cpu_seconds_total',
#                                                                                               'type': 'COUNTER'},
#                                        'go_cpu_classes_gc_mark_idle_cpu_seconds_total': {'help': 'Estimated '
#                                                                                                  'total '
#                                                                                                  'CPU '
#                                                                                                  'time '
#                                                                                                  'spent '
#                                                                                                  'performing '
#                                                                                                  'GC '
#                                                                                                  'tasks '
#                                                                                                  'on '
#                                                                                                  'spare '
#                                                                                                  'CPU '
#                                                                                                  'resources '
#                                                                                                  'that '
#                                                                                                  'the '
#                                                                                                  'Go '
#                                                                                                  'scheduler '
#                                                                                                  'could '
#                                                                                                  'not '
#                                                                                                  'otherwise '
#                                                                                                  'find '
#                                                                                                  'a '
#                                                                                                  'use '
#                                                                                                  'for. '
#                                                                                                  'This '
#                                                                                                  'should '
#                                                                                                  'be '
#                                                                                                  'subtracted '
#                                                                                                  'from '
#                                                                                                  'the '
#                                                                                                  'total '
#                                                                                                  'GC '
#                                                                                                  'CPU '
#                                                                                                  'time '
#                                                                                                  'to '
#                                                                                                  'obtain '
#                                                                                                  'a '
#                                                                                                  'measure '
#                                                                                                  'of '
#                                                                                                  'compulsory '
#                                                                                                  'GC '
#                                                                                                  'CPU '
#                                                                                                  'time. '
#                                                                                                  'This '
#                                                                                                  'metric '
#                                                                                                  'is '
#                                                                                                  'an '
#                                                                                                  'overestimate, '
#                                                                                                  'and '
#                                                                                                  'not '
#                                                                                                  'directly '
#                                                                                                  'comparable '
#                                                                                                  'to '
#                                                                                                  'system '
#                                                                                                  'CPU '
#                                                                                                  'time '
#                                                                                                  'measurements. '
#                                                                                                  'Compare '
#                                                                                                  'only '
#                                                                                                  'with '
#                                                                                                  'other '
#                                                                                                  '/cpu/classes '
#                                                                                                  'metrics.',
#                                                                                          'metric': [{'counter': {'value': 0.020747155}}],
#                                                                                          'name': 'go_cpu_classes_gc_mark_idle_cpu_seconds_total',
#                                                                                          'type': 'COUNTER'},
#                                        'go_cpu_classes_gc_pause_cpu_seconds_total': {'help': 'Estimated '
#                                                                                              'total '
#                                                                                              'CPU '
#                                                                                              'time '
#                                                                                              'spent '
#                                                                                              'with '
#                                                                                              'the '
#                                                                                              'application '
#                                                                                              'paused '
#                                                                                              'by '
#                                                                                              'the '
#                                                                                              'GC. '
#                                                                                              'Even '
#                                                                                              'if '
#                                                                                              'only '
#                                                                                              'one '
#                                                                                              'thread '
#                                                                                              'is '
#                                                                                              'running '
#                                                                                              'during '
#                                                                                              'the '
#                                                                                              'pause, '
#                                                                                              'this '
#                                                                                              'is '
#                                                                                              'computed '
#                                                                                              'as '
#                                                                                              'GOMAXPROCS '
#                                                                                              'times '
#                                                                                              'the '
#                                                                                              'pause '
#                                                                                              'latency '
#                                                                                              'because '
#                                                                                              'nothing '
#                                                                                              'else '
#                                                                                              'can '
#                                                                                              'be '
#                                                                                              'executing. '
#                                                                                              'This '
#                                                                                              'is '
#                                                                                              'the '
#                                                                                              'exact '
#                                                                                              'sum '
#                                                                                              'of '
#                                                                                              'samples '
#                                                                                              'in '
#                                                                                              '/gc/pause:seconds '
#                                                                                              'if '
#                                                                                              'each '
#                                                                                              'sample '
#                                                                                              'is '
#                                                                                              'multiplied '
#                                                                                              'by '
#                                                                                              'GOMAXPROCS '
#                                                                                              'at '
#                                                                                              'the '
#                                                                                              'time '
#                                                                                              'it '
#                                                                                              'is '
#                                                                                              'taken. '
#                                                                                              'This '
#                                                                                              'metric '
#                                                                                              'is '
#                                                                                              'an '
#                                                                                              'overestimate, '
#                                                                                              'and '
#                                                                                              'not '
#                                                                                              'directly '
#                                                                                              'comparable '
#                                                                                              'to '
#                                                                                              'system '
#                                                                                              'CPU '
#                                                                                              'time '
#                                                                                              'measurements. '
#                                                                                              'Compare '
#                                                                                              'only '
#                                                                                              'with '
#                                                                                              'other '
#                                                                                              '/cpu/classes '
#                                                                                              'metrics.',
#                                                                                      'metric': [{'counter': {'value': 0.024531072}}],
#                                                                                      'name': 'go_cpu_classes_gc_pause_cpu_seconds_total',
#                                                                                      'type': 'COUNTER'},
#                                        'go_cpu_classes_gc_total_cpu_seconds_total': {'help': 'Estimated '
#                                                                                              'total '
#                                                                                              'CPU '
#                                                                                              'time '
#                                                                                              'spent '
#                                                                                              'performing '
#                                                                                              'GC '
#                                                                                              'tasks. '
#                                                                                              'This '
#                                                                                              'metric '
#                                                                                              'is '
#                                                                                              'an '
#                                                                                              'overestimate, '
#                                                                                              'and '
#                                                                                              'not '
#                                                                                              'directly '
#                                                                                              'comparable '
#                                                                                              'to '
#                                                                                              'system '
#                                                                                              'CPU '
#                                                                                              'time '
#                                                                                              'measurements. '
#                                                                                              'Compare '
#                                                                                              'only '
#                                                                                              'with '
#                                                                                              'other '
#                                                                                              '/cpu/classes '
#                                                                                              'metrics. '
#                                                                                              'Sum '
#                                                                                              'of '
#                                                                                              'all '
#                                                                                              'metrics '
#                                                                                              'in '
#                                                                                              '/cpu/classes/gc.',
#                                                                                      'metric': [{'counter': {'value': 0.082199663}}],
#                                                                                      'name': 'go_cpu_classes_gc_total_cpu_seconds_total',
#                                                                                      'type': 'COUNTER'},
#                                        'go_cpu_classes_idle_cpu_seconds_total': {'help': 'Estimated '
#                                                                                          'total '
#                                                                                          'available '
#                                                                                          'CPU '
#                                                                                          'time '
#                                                                                          'not '
#                                                                                          'spent '
#                                                                                          'executing '
#                                                                                          'any '
#                                                                                          'Go '
#                                                                                          'or '
#                                                                                          'Go '
#                                                                                          'runtime '
#                                                                                          'code. '
#                                                                                          'In '
#                                                                                          'other '
#                                                                                          'words, '
#                                                                                          'the '
#                                                                                          'part '
#                                                                                          'of '
#                                                                                          '/cpu/classes/total:cpu-seconds '
#                                                                                          'that '
#                                                                                          'was '
#                                                                                          'unused. '
#                                                                                          'This '
#                                                                                          'metric '
#                                                                                          'is '
#                                                                                          'an '
#                                                                                          'overestimate, '
#                                                                                          'and '
#                                                                                          'not '
#                                                                                          'directly '
#                                                                                          'comparable '
#                                                                                          'to '
#                                                                                          'system '
#                                                                                          'CPU '
#                                                                                          'time '
#                                                                                          'measurements. '
#                                                                                          'Compare '
#                                                                                          'only '
#                                                                                          'with '
#                                                                                          'other '
#                                                                                          '/cpu/classes '
#                                                                                          'metrics.',
#                                                                                  'metric': [{'counter': {'value': 9519.781520582}}],
#                                                                                  'name': 'go_cpu_classes_idle_cpu_seconds_total',
#                                                                                  'type': 'COUNTER'},
#                                        'go_cpu_classes_scavenge_assist_cpu_seconds_total': {'help': 'Estimated '
#                                                                                                     'total '
#                                                                                                     'CPU '
#                                                                                                     'time '
#                                                                                                     'spent '
#                                                                                                     'returning '
#                                                                                                     'unused '
#                                                                                                     'memory '
#                                                                                                     'to '
#                                                                                                     'the '
#                                                                                                     'underlying '
#                                                                                                     'platform '
#                                                                                                     'in '
#                                                                                                     'response '
#                                                                                                     'eagerly '
#                                                                                                     'in '
#                                                                                                     'response '
#                                                                                                     'to '
#                                                                                                     'memory '
#                                                                                                     'pressure. '
#                                                                                                     'This '
#                                                                                                     'metric '
#                                                                                                     'is '
#                                                                                                     'an '
#                                                                                                     'overestimate, '
#                                                                                                     'and '
#                                                                                                     'not '
#                                                                                                     'directly '
#                                                                                                     'comparable '
#                                                                                                     'to '
#                                                                                                     'system '
#                                                                                                     'CPU '
#                                                                                                     'time '
#                                                                                                     'measurements. '
#                                                                                                     'Compare '
#                                                                                                     'only '
#                                                                                                     'with '
#                                                                                                     'other '
#                                                                                                     '/cpu/classes '
#                                                                                                     'metrics.',
#                                                                                             'metric': [{'counter': {'value': 2.23e-07}}],
#                                                                                             'name': 'go_cpu_classes_scavenge_assist_cpu_seconds_total',
#                                                                                             'type': 'COUNTER'},
#                                        'go_cpu_classes_scavenge_background_cpu_seconds_total': {'help': 'Estimated '
#                                                                                                         'total '
#                                                                                                         'CPU '
#                                                                                                         'time '
#                                                                                                         'spent '
#                                                                                                         'performing '
#                                                                                                         'background '
#                                                                                                         'tasks '
#                                                                                                         'to '
#                                                                                                         'return '
#                                                                                                         'unused '
#                                                                                                         'memory '
#                                                                                                         'to '
#                                                                                                         'the '
#                                                                                                         'underlying '
#                                                                                                         'platform. '
#                                                                                                         'This '
#                                                                                                         'metric '
#                                                                                                         'is '
#                                                                                                         'an '
#                                                                                                         'overestimate, '
#                                                                                                         'and '
#                                                                                                         'not '
#                                                                                                         'directly '
#                                                                                                         'comparable '
#                                                                                                         'to '
#                                                                                                         'system '
#                                                                                                         'CPU '
#                                                                                                         'time '
#                                                                                                         'measurements. '
#                                                                                                         'Compare '
#                                                                                                         'only '
#                                                                                                         'with '
#                                                                                                         'other '
#                                                                                                         '/cpu/classes '
#                                                                                                         'metrics.',
#                                                                                                 'metric': [{'counter': {'value': 0.001219738}}],
#                                                                                                 'name': 'go_cpu_classes_scavenge_background_cpu_seconds_total',
#                                                                                                 'type': 'COUNTER'},
#                                        'go_cpu_classes_scavenge_total_cpu_seconds_total': {'help': 'Estimated '
#                                                                                                    'total '
#                                                                                                    'CPU '
#                                                                                                    'time '
#                                                                                                    'spent '
#                                                                                                    'performing '
#                                                                                                    'tasks '
#                                                                                                    'that '
#                                                                                                    'return '
#                                                                                                    'unused '
#                                                                                                    'memory '
#                                                                                                    'to '
#                                                                                                    'the '
#                                                                                                    'underlying '
#                                                                                                    'platform. '
#                                                                                                    'This '
#                                                                                                    'metric '
#                                                                                                    'is '
#                                                                                                    'an '
#                                                                                                    'overestimate, '
#                                                                                                    'and '
#                                                                                                    'not '
#                                                                                                    'directly '
#                                                                                                    'comparable '
#                                                                                                    'to '
#                                                                                                    'system '
#                                                                                                    'CPU '
#                                                                                                    'time '
#                                                                                                    'measurements. '
# ...
#                                                                                   'type': 'COUNTER'},
#                                        'go_threads': {'help': 'Number of OS '
#                                                               'threads '
#                                                               'created.',
#                                                       'metric': [{'gauge': {'value': 22}}],
#                                                       'name': 'go_threads',
#                                                       'type': 'GAUGE'},
#                                        'http_request_duration_seconds': {'help': 'A '
#                                                                                  'histogram '
#                                                                                  'of '
#                                                                                  'duration '
#                                                                                  'for '
#                                                                                  'requests.',
#                                                                          'metric': [{'histogram': {'bucket': [{'cumulativeCount': '0',
#                                                                                                                'upperBound': 1e-06},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 5e-06},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 1e-05},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 5e-05},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 0.0001},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 0.0005},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 0.001},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 0.01},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 0.1},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 1}],
#                                                                                                    'sampleCount': '1',
#                                                                                                    'sampleSum': 0.000367605},
#                                                                                      'label': [{'name': 'code',
#                                                                                                 'value': '200'},
#                                                                                                {'name': 'handler',
#                                                                                                 'value': 'health'},
#                                                                                                {'name': 'method',
#                                                                                                 'value': 'get'}]},
#                                                                                     {'histogram': {'bucket': [{'cumulativeCount': '0',
#                                                                                                                'upperBound': 1e-06},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 5e-06},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 1e-05},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 5e-05},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 0.0001},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 0.0005},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 0.001},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 0.01},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 0.1},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 1}],
#                                                                                                    'sampleCount': '1',
#                                                                                                    'sampleSum': 0.000247179},
#                                                                                      'label': [{'name': 'code',
#                                                                                                 'value': '200'},
#                                                                                                {'name': 'handler',
#                                                                                                 'value': 'v1/config'},
#                                                                                                {'name': 'method',
#                                                                                                 'value': 'get'}]},
#                                                                                     {'histogram': {'bucket': [{'cumulativeCount': '0',
#                                                                                                                'upperBound': 1e-06},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 5e-06},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 1e-05},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 5e-05},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 0.0001},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 0.0005},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 0.001},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 0.01},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 0.1},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 1}],
#                                                                                                    'sampleCount': '1',
#                                                                                                    'sampleSum': 0.002469533},
#                                                                                      'label': [{'name': 'code',
#                                                                                                 'value': '200'},
#                                                                                                {'name': 'handler',
#                                                                                                 'value': 'v1/query'},
#                                                                                                {'name': 'method',
#                                                                                                 'value': 'post'}]},
#                                                                                     {'histogram': {'bucket': [{'cumulativeCount': '0',
#                                                                                                                'upperBound': 1e-06},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 5e-06},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 1e-05},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 5e-05},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 0.0001},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 0.0005},
#                                                                                                               {'cumulativeCount': '0',
#                                                                                                                'upperBound': 0.001},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 0.01},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 0.1},
#                                                                                                               {'cumulativeCount': '1',
#                                                                                                                'upperBound': 1}],
#                                                                                                    'sampleCount': '1',
#                                                                                                    'sampleSum': 0.002438255},
#                                                                                      'label': [{'name': 'code',
#                                                                                                 'value': '200'},
#                                                                                                {'name': 'handler',
#                                                                                                 'value': 'v1/status'},
#                                                                                                {'name': 'method',
#                                                                                                 'value': 'get'}]}],
#                                                                          'name': 'http_request_duration_seconds',
#                                                                          'type': 'HISTOGRAM'}}},
#             'plugins': {'decision_logs': {'state': 'OK'},
#                         'discovery': {'state': 'OK'},
#                         'status': {'state': 'OK'}}}}

# %% [markdown]
# # Decison Logs

# %%
url = URL_PREFIX + '/206a3f36-1a21-4014-992b-01a57f168d06'
params = {}
print(f'Request:\nurl={url}\nheaders={headers}\nparms={params}')

r = requests.post(url=url, headers=headers, params=params)
_dump(r)
# Out:
# Request:
# url=http://localhost:8181/206a3f36-1a21-4014-992b-01a57f168d06
# headers={'content-type': 'application/json'}
# parms={}
#
# Response:
# 404
# 404 page not found

# %% [markdown]
# # Use Cases

# %% [markdown]
# ## HTTP API
#
# https://www.openpolicyagent.org/docs/latest/http-api-authorization/

# %%
# 1 Create Policy
headers['content-type'] = 'text/plain'
policy_id = 'httpapi.authz'
url = URL_PREFIX + f'/v1/policies/{policy_id}'
params = {}
data = """package httpapi.authz

import rego.v1

# bob is alice's manager, and betty is charlie's.
subordinates := {"alice": [], "charlie": [], "bob": ["alice"], "betty": ["charlie"]}

default allow := false

# Allow users to get their own salaries.
allow if {
	input.method == "GET"
	input.path == ["finance", "salary", input.user]
}

# Allow managers to get their subordinates' salaries.
allow if {
	some username
	input.method == "GET"
	input.path = ["finance", "salary", username]
	subordinates[input.user][_] == username
}"""
r = requests.put(url=url, headers=headers, params=params, data=data)
_dump(r)
headers['content-type'] = 'application/json'
# Out:
# Response:
# 200
# {}

# %%
# Query
url = URL_PREFIX + '/v1/data' + '/httpapi/authz'
print(url)
params = {}

# alice -> alice
data = {
    "input": {
        "method": "GET",
        "path": [
            "finance",
            "salary",
            "alice"
        ],
        "user": "alice"
    }
}
r = requests.post(url=url, headers=headers, params=params, data=json.dumps(data))
_dump(r)

# bob -> alice
data = {
    "input": {
        "method": "GET",
        "path": [
            "finance",
            "salary",
            "alice"
        ],
        "user": "bob"
    }
}
r = requests.post(url=url, headers=headers, params=params, data=json.dumps(data))
_dump(r)

# bob -> charlie
url = URL_PREFIX + '/v1/data' + '/httpapi/authz/allow' # Only query 'allow'

data = {
    "input": {
        "method": "GET",
        "path": [
            "finance",
            "salary",
            "charlie"
        ],
        "user": "bob"
    }
}
r = requests.post(url=url, headers=headers, params=params, data=json.dumps(data))
_dump(r)
# Out:
# http://localhost:8181/v1/data/httpapi/authz
#
# Response:
# 200
# {'decision_id': '4a059620-a328-4b86-abfc-dcfcb6536ab0',
#  'result': {'allow': True,
#             'subordinates': {'alice': [],
#                              'betty': ['charlie'],
#                              'bob': ['alice'],
#                              'charlie': []}}}
#
# Response:
# 200
# {'decision_id': '71ed5bbe-e010-4ad6-b742-08a116a34026',
#  'result': {'allow': True,
#             'subordinates': {'alice': [],
#                              'betty': ['charlie'],
#                              'bob': ['alice'],
#                              'charlie': []}}}
#
# Response:
# 200
# {'decision_id': '9be65e16-4249-4975-a439-e6322d2fd8a1', 'result': False}
