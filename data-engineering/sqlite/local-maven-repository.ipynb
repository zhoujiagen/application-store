# %% [markdown]
# ## Read Respository

# %%
from pathlib import Path
import pandas as pd
from datetime import datetime
import time

# verify with shell: find . | grep -E 'jar$' | wc -l
def list_artifact(starting_directory : str, glob="*") -> list[str]:
    poms = []
    path_object = Path(starting_directory)
    for file_path in path_object.rglob(glob):
        if file_path.is_file():
            stat = file_path.stat()
            p = file_path.as_posix()
            if p.find('-sources.jar') != -1: # skip sources
                continue
            if p.find('SNAPSHOT') != -1 and not p.endswith('-SNAPSHOT.jar'): # skip sources
                continue
            artifacts = p.removeprefix(starting_directory).split('/')
            # print(artifacts)
            poms.append({
                # 'folder': file_path.parent.as_posix(),
                # 'path': artifacts,
                'group': '.'.join(artifacts[:-3]),
                'artifact':  artifacts[-3],
                'version': artifacts[-2],
                'size': stat.st_size, # / 1024 / 1024, # MB
                'ctime': datetime.fromtimestamp(stat.st_ctime).strftime('%Y-%m-%d %H:%M:%S.%f'),
                'jar': artifacts[-1]
            })
    return poms

artifact_home = "C:/Users/zhouj/.m2/repository/"
artifacts = list_artifact(artifact_home, "*.jar")
# pd.json_normalize(artifacts)
print(len(artifacts))
s = pd.json_normalize(artifacts)
# s.sort_values(by=['size', 'group', 'artifact'], ascending=False)
# s['path.size'].sum()

s.sort_values(by=['ctime'], ascending=True)
# Out:
# 2592
#                           group                 artifact version      size  \
# 1334   org.apache.maven.plugins       maven-clean-plugin   3.2.0     35678
# 1416    org.apache.maven.shared       maven-shared-utils   3.3.4    153143
# 500                  commons-io               commons-io     2.6    214788
# 1355   org.apache.maven.plugins   maven-resources-plugin   3.3.0     31760
# 1336   org.apache.maven.plugins    maven-compiler-plugin  3.10.1     61899
# ...                         ...                      ...     ...       ...
# 2163         org.junit.platform  junit-platform-launcher   1.3.1     94645
# 1445  org.apache.maven.surefire  surefire-junit-platform  2.22.2     65915
# 1611            org.apiguardian          apiguardian-api   1.0.0      2164
# 2234             org.opentest4j               opentest4j   1.1.1      7121
# 2268                org.rocksdb               rocksdbjni   9.4.0  70111775
#
#                            ctime                                 jar
# 1334  2024-03-07 12:43:26.969265        maven-clean-plugin-3.2.0.jar
# 1416  2024-03-07 12:43:36.989123        maven-shared-utils-3.3.4.jar
# 500   2024-03-07 12:43:42.467580                  commons-io-2.6.jar
# 1355  2024-03-07 12:44:03.833816    maven-resources-plugin-3.3.0.jar
# 1336  2024-03-07 12:44:05.852205    maven-compiler-plugin-3.10.1.jar
# ...                          ...                                 ...
# 2163  2024-08-06 09:08:39.365935   junit-platform-launcher-1.3.1.jar
# 1445  2024-08-06 09:08:39.866519  surefire-junit-platform-2.22.2.jar
# 1611  2024-08-06 09:08:40.663393           apiguardian-api-1.0.0.jar
# 2234  2024-08-06 09:08:49.388928                opentest4j-1.1.1.jar
# 2268  2024-08-07 11:15:18.763036                rocksdbjni-9.4.0.jar
#
# [2592 rows x 6 columns]

# %%
# https://pypi.org/project/ipython-sql/

# install:
# !pip install ipython-sql

# %%
# %load_ext sql
# %reload_ext sql

# %%
# %sql sqlite:///data/maven.db

# %%
values = []
for i in range(len(artifacts)):
    values.append("('{group}', '{artifact}', '{version}', '{jar}', {size}, '{ctime}')".format(
        group=artifacts[i]['group'],
        artifact=artifacts[i]['artifact'],
        version=artifacts[i]['version'],
        jar=artifacts[i]['jar'],
        size=artifacts[i]['size'],
        ctime=artifacts[i]['ctime']
    ))
sql_values = ",".join(values)

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS `artifacts` (
#     `group` varchar(128) NOT NULL,
#     `artifact` varchar(128) NOT NULL,
#     `version` varchar(128) NOT NULL,
#     `jar` varchar(128)  NOT NULL,
#     `size` INT NOT NULL,
#     `ctime` DATETIME NOT NULL);
# DELETE FROM `artifacts`;
# INSERT INTO `artifacts`(`group`,`artifact`,`version`,`jar`, `size`,`ctime`)
# VALUES
# {sql_values}
# ;
# Out:
#  * sqlite:///data/maven.db
# Done.
# 2592 rows affected.
# 2592 rows affected.
# []

# %%
# %%sql
# SELECT `group`, artifact, `version`, COUNT(*) AS c
# FROM artifacts
# GROUP BY `group`, artifact, `version`
# HAVING c > 1
# ORDER BY c DESC;
# Out:
#  * sqlite:///data/maven.db
# Done.
# [('org.bytedeco', 'javacpp', '1.5.6', 16),
#  ('org.bytedeco', 'artoolkitplus', '2.3.1-1.5.9', 13),
#  ('org.bytedeco', 'ffmpeg', '4.4-1.5.6', 13),
#  ('org.bytedeco.javacpp-presets', 'ffmpeg', '4.0.2-1.4.3', 12),
#  ('org.bytedeco', 'javacpp', '1.5.10', 11),
#  ('org.bytedeco', 'openblas', '0.3.26-1.5.10', 11),
#  ('org.bytedeco', 'opencv', '4.9.0-1.5.10', 11),
#  ('org.bytedeco', 'ffmpeg', '6.1.1-1.5.10', 9),
#  ('org.bytedeco', 'leptonica', '1.84.1-1.5.10', 9),
#  ('org.bytedeco', 'libdc1394', '2.2.6-1.5.9', 9),
#  ('org.bytedeco', 'libfreenect', '0.5.7-1.5.9', 9),
#  ('org.bytedeco', 'tesseract', '5.3.4-1.5.10', 9),
#  ('org.bytedeco', 'librealsense', '1.12.4-1.5.9', 8),
#  ('org.bytedeco', 'librealsense2', '2.53.1-1.5.9', 8),
#  ('org.bytedeco', 'flycapture', '2.13.3.31-1.5.9', 7),
#  ('org.bytedeco', 'libfreenect2', '0.2.0-1.5.9', 5),
#  ('io.netty', 'netty-transport-native-epoll', '4.1.79.Final', 3),
#  ('io.netty', 'netty-transport-native-epoll', '4.1.84.Final', 3),
#  ('org.bytedeco', 'videoinput', '0.200-1.5.9', 3),
#  ('io.netty', 'netty-resolver-dns-native-macos', '4.1.79.Final', 2),
#  ('io.netty', 'netty-resolver-dns-native-macos', '4.1.84.Final', 2),
#  ('io.netty', 'netty-transport-native-kqueue', '4.1.79.Final', 2),
#  ('io.netty', 'netty-transport-native-kqueue', '4.1.84.Final', 2),
#  ('org.openjfx', 'javafx-base', '17', 2),
#  ('org.openjfx', 'javafx-graphics', '17', 2)]

# %%
# %%sql
# SELECT * FROM artifacts
# WHERE `group` = 'org.bytedeco' AND artifact = 'javacpp'
# ORDER BY size DESC;
# Out:
#  * sqlite:///data/maven.db
# Done.
# [('org.bytedeco', 'javacpp', '1.5.10', 'javacpp-1.5.10-windows-x86_64.jar', 1406379, '2024-07-25 18:33:21.958724'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-windows-x86_64.jar', 1305252, '2024-08-05 16:42:03.265707'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-windows-x86.jar', 1287718, '2024-08-05 16:42:08.945045'),
#  ('org.bytedeco', 'javacpp', '1.5.10', 'javacpp-1.5.10.jar', 506608, '2024-07-25 18:29:23.835263'),
#  ('org.bytedeco', 'javacpp', '1.5.9', 'javacpp-1.5.9.jar', 501606, '2024-07-25 18:29:22.545120'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6.jar', 487566, '2024-08-05 16:42:03.689718'),
#  ('org.bytedeco', 'javacpp', '1.4.3', 'javacpp-1.4.3.jar', 372427, '2024-08-05 16:41:52.531631'),
#  ('org.bytedeco', 'javacpp', '1.5.10', 'javacpp-1.5.10-android-x86_64.jar', 97254, '2024-07-25 18:33:41.640944'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-android-x86.jar', 92111, '2024-08-05 16:42:04.723573'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-android-x86_64.jar', 91983, '2024-08-05 16:42:05.131763'),
#  ('org.bytedeco', 'javacpp', '1.5.10', 'javacpp-1.5.10-android-arm64.jar', 88623, '2024-07-25 18:33:38.881179'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-android-arm64.jar', 86372, '2024-08-05 16:42:04.350070'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-android-arm.jar', 63104, '2024-08-05 16:42:04.028710'),
#  ('org.bytedeco', 'javacpp', '1.5.10', 'javacpp-1.5.10-linux-ppc64le.jar', 27933, '2024-07-25 18:32:25.589496'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-linux-x86.jar', 27084, '2024-08-05 16:42:07.227107'),
#  ('org.bytedeco', 'javacpp', '1.5.10', 'javacpp-1.5.10-linux-x86_64.jar', 26488, '2024-07-25 18:32:34.632657'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-linux-ppc64le.jar', 25995, '2024-08-05 16:42:06.845407'),
#  ('org.bytedeco', 'javacpp', '1.5.10', 'javacpp-1.5.10-linux-arm64.jar', 25695, '2024-07-25 18:33:46.061766'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-linux-x86_64.jar', 25611, '2024-08-05 16:42:07.578704'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-linux-arm64.jar', 24393, '2024-08-05 16:42:06.465760'),
#  ('org.bytedeco', 'javacpp', '1.5.10', 'javacpp-1.5.10-ios-arm64.jar', 23794, '2024-07-25 18:33:43.080395'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-ios-arm64.jar', 23576, '2024-08-05 16:42:05.517363'),
#  ('org.bytedeco', 'javacpp', '1.5.10', 'javacpp-1.5.10-macosx-x86_64.jar', 22303, '2024-07-25 18:32:41.683640'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-linux-armhf.jar', 22193, '2024-08-05 16:42:06.146303'),
#  ('org.bytedeco', 'javacpp', '1.5.10', 'javacpp-1.5.10-ios-x86_64.jar', 22127, '2024-07-25 18:33:44.415816'),
#  ('org.bytedeco', 'javacpp', '1.5.10', 'javacpp-1.5.10-macosx-arm64.jar', 22032, '2024-07-25 18:32:39.754957'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-macosx-x86_64.jar', 21901, '2024-08-05 16:42:08.225557'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-ios-x86_64.jar', 21840, '2024-08-05 16:42:05.837604'),
#  ('org.bytedeco', 'javacpp', '1.5.6', 'javacpp-1.5.6-macosx-arm64.jar', 21805, '2024-08-05 16:42:07.911923')]
